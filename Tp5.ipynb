# %%
pip install PyXAI
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PyXAI (from versions: none)
# ERROR: No matching distribution found for PyXAI

# %%
from pyxai import Learning, Explainer
learner = LearningScikitlearn(df,learner_type=Learning.CLASSIFICATION)
# Decision Tree
model_dt = learner.evaluate(method=Learning.HOLD_OUT, output=Learning.DT, learner_options={'max_depth': 5, 'random_state': 42})
# Random Forest 
model_rf = learner.evaluate(method=Learning.HOLD_OUT, output=Learning.RF, learner_options={'n_estimators': 100, 'random_state': 42})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pyxai import Learning, Explainer
#       2 learner = LearningScikitlearn(df,learner_type=Learning.CLASSIFICATION)
#       3 # Decision Tree
#
# ModuleNotFoundError: No module named 'pyxai'
